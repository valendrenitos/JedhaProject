# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("data/licenses_by_year_region_fed.csv")

df
# Out:
#        annee                region                          nom_fed  \
# 0       2012  Auvergne-Rhône-Alpes                    AEROMODELISME
# 1       2012  Auvergne-Rhône-Alpes                      AEROSTATION
# 2       2012  Auvergne-Rhône-Alpes  AIKIDO AIKIBUDO ET AFFINITAIRES
# 3       2012  Auvergne-Rhône-Alpes                   AIKIDO ET BUDO
# 4       2012  Auvergne-Rhône-Alpes                       ATHLETISME
# ...      ...                   ...                              ...
# 18779   2023         Île-de-France                            VOILE
# 18780   2023         Île-de-France        VOITURES RADIO COMMANDEES
# 18781   2023         Île-de-France                   VOL EN PLANEUR
# 18782   2023         Île-de-France                        VOL LIBRE
# 18783   2023         Île-de-France                           VOLLEY
#
#        total_license  total_f  total_h   h_1_9  h_10_19  h_20_29  h_30_59  \
# 0             2494.0     61.0   2433.0    20.0    298.0    142.0   1251.0
# ...

# %%
df["annee"] = df['annee'].astype(str)

numeric_cols = ["total_license", "total_f", "total_h","f_1_9", "f_10_19", "f_20_29","f_30_59","f_60_74","f_75","h_1_9", "h_10_19", "h_20_29","h_30_59","h_60_74","h_75"]
df[numeric_cols] = df[numeric_cols].astype(int)

# %%
df
# Out:
#       annee                region                          nom_fed  \
# 0      2012  Auvergne-Rhône-Alpes                    AEROMODELISME
# 1      2012  Auvergne-Rhône-Alpes                      AEROSTATION
# 2      2012  Auvergne-Rhône-Alpes  AIKIDO AIKIBUDO ET AFFINITAIRES
# 3      2012  Auvergne-Rhône-Alpes                   AIKIDO ET BUDO
# 4      2012  Auvergne-Rhône-Alpes                       ATHLETISME
# ...     ...                   ...                              ...
# 18779  2023         Île-de-France                            VOILE
# 18780  2023         Île-de-France        VOITURES RADIO COMMANDEES
# 18781  2023         Île-de-France                   VOL EN PLANEUR
# 18782  2023         Île-de-France                        VOL LIBRE
# 18783  2023         Île-de-France                           VOLLEY
#
#        total_license  total_f  total_h  h_1_9  h_10_19  h_20_29  h_30_59  \
# 0               2494       61     2433     20      298      142     1251
# ...

# %%
display(100 * df.isnull().sum() / df.shape[0])
# Out:
# annee            0.0
# region           0.0
# nom_fed          0.0
# total_license    0.0
# total_f          0.0
# total_h          0.0
# h_1_9            0.0
# h_10_19          0.0
# h_20_29          0.0
# h_30_59          0.0
# h_60_74          0.0
# h_75             0.0
# f_1_9            0.0
# f_10_19          0.0
# f_20_29          0.0
# f_30_59          0.0
# f_60_74          0.0
# f_75             0.0
# dtype: float64

# %%
df = df[df["total_license"] > 0]
df["part_f"] = df["total_f"] / df["total_license"]

target = "part_f"

Y = df.loc[:,target]
X = df.drop(target, axis=1)

print(X)
print(Y)
# Out:
#       annee                region                          nom_fed  \
# 0      2012  Auvergne-Rhône-Alpes                    AEROMODELISME
# 1      2012  Auvergne-Rhône-Alpes                      AEROSTATION
# 2      2012  Auvergne-Rhône-Alpes  AIKIDO AIKIBUDO ET AFFINITAIRES
# 3      2012  Auvergne-Rhône-Alpes                   AIKIDO ET BUDO
# 4      2012  Auvergne-Rhône-Alpes                       ATHLETISME
# ...     ...                   ...                              ...
# 18779  2023         Île-de-France                            VOILE
# 18780  2023         Île-de-France        VOITURES RADIO COMMANDEES
# 18781  2023         Île-de-France                   VOL EN PLANEUR
# 18782  2023         Île-de-France                        VOL LIBRE
# 18783  2023         Île-de-France                           VOLLEY
#
#        total_license  total_f  total_h  h_1_9  h_10_19  h_20_29  h_30_59  \
# 0               2494       61     2433     20      298      142     1251
# ...

# %%
X_train, X_test, y_train, y_test= train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
numeric_features = ["h_1_9", "h_10_19", "h_20_29","h_30_59","h_60_74","h_75"]
numeric_transformer = Pipeline(
    steps=[
        ("scaler", StandardScaler())
    ]
)

# %%
categorical_features = ["annee","region","nom_fed"]
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ( "encoder", OneHotEncoder(drop="first"))
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

# %%
# Preprocessings on train set
print("Performing preprocessings on train set...")
print(X_train.head())

model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("regressor", LinearRegression())
    ]
)

model.fit(X_train, y_train)
print("...Done.")
# Out:
# Performing preprocessings on train set...
#       annee                     region  \
# 12675  2020                  Occitanie
# 6392   2016           Pays de la Loire
# 8049   2017  Provence-Alpes-Côte dAzur
# 1489   2013        Centre-Val de Loire
# 7261   2017                  Grand Est
#
#                                           nom_fed  total_license  total_f  \
# 12675                                         SKI          10121     3823
# 6392                                 PARACHUTISME            524       77
# 8049                                  GYMNASTIQUE          20555    16887
# 1489                                        DANSE           2728     2573
# 7261   UNION SPORTIVE LENSEIGNEMENT PREMIER DEGRE          90908    45345
#
#        total_h  h_1_9  h_10_19  h_20_29  h_30_59  h_60_74  h_75  f_1_9  \
# 12675     6298   1207     1986      412     1885      703    82   1027
# 6392       447      0       43      130      249       24     1      0
# ...

# %%
print("Train R2:",model.score(X_train, y_train))
print("Test R2:",model.score(X_test, y_test))
# Out:
# Train R2: 0.21624473798327482
# Test R2: 0.03282825752690943

# %% [markdown]
# 👉 Ton modèle explique 21% de la variance en train \
# 👉 Mais quasiment rien en test
#
# On est face à un problème de généralisation.

# %% [markdown]
# 👉 La part féminine est probablement déterminée par :\
# 	•	culture sportive propre à chaque fédération\
# 	•	dynamique historique \
# 	•	inertie forte \
# 	•	facteurs socio-économiques absents de ton dataset\
# \
# Donc ton modèle linéaire capte peu d’information structurelle.

# %%
from sklearn.metrics import mean_absolute_error

y_pred = model.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("Moyenne part_f:", y_test.mean())
# Out:
# MAE: 0.13082180301331411
# Moyenne part_f: 0.3450304611546037

# %% [markdown]
# 👉 L’erreur moyenne est d’environ 10 points de pourcentage \
# 👉 La part moyenne est 36% \
# 👉 Donc il n’est pas exploitable pour de la décision publique.
#
# Et ça confirme le R² test = 0.03 :
# il n’explique quasiment rien.

# %%
df = df.sort_values(["nom_fed","region","annee"])
df["part_f_lag1"] = df.groupby(["nom_fed","region"])["part_f"].shift(1)

df_model = df.dropna(subset=["part_f_lag1"])

Y = df_model["part_f"]
X = df_model[["part_f_lag1"]]

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print("Train R2:", model.score(X_train, y_train))
print("Test R2:", model.score(X_test, y_test))
# Out:
# Train R2: 0.1934810168898231
# Test R2: 0.05004241502163287

# %%
df_model = df_model.sort_values("annee")

train = df_model[df_model["annee"] < "2022"]
test  = df_model[df_model["annee"] >= "2022"]

X_train = train[["part_f_lag1"]]
y_train = train["part_f"]

X_test = test[["part_f_lag1"]]
y_test = test["part_f"]

model = LinearRegression()
model.fit(X_train, y_train)

print("Train R2:", model.score(X_train, y_train))
print("Test R2:", model.score(X_test, y_test))
# Out:
# Train R2: 0.0784588670405928
# Test R2: 0.42875850800818616

# %% [markdown]
# Un R² test beaucoup plus élevé que le train, ce n’est pas “magique” — ça veut dire qu’on a changé la structure du problème.

# %% [markdown]
# 🎯 Interprétation correcte
#
# Tu as maintenant :
# 	•	Split temporel (donc cohérent)
# 	•	Modèle très simple (probablement part_f_lag1 seul)
#
# Ce que ça dit :
#
# 👉 La féminisation est principalement inertielle
# 👉 La meilleure prédiction de l’année t est l’année t-1
# 👉 Le modèle capte une vraie dynamique temporelle
#
# ⸻
#
# 🧠 Pourquoi le R² train est plus faible ?
#
# Deux raisons possibles :
#
# 1️⃣ Variance plus forte dans le train
#
# Peut-être que les années anciennes ont plus de volatilité.
#
# 2️⃣ Moins d’années en test
#
# Le R² dépend de la variance du y.
# Si la variance est plus forte dans le test, le R² peut mécaniquement être plus élevé.
